# %%
import sys
# print(sys.path)
sys.path.insert(0,'..')
# print(sys.path)

# %%
from Prob_torch_BSB_Raissi import BSB_Raissi
print( BSB_Raissi.__doc__ )
print( BSB_Raissi.__init__.__doc__ )
# Out:
#     class BSB_Raissi(FBSNN_torch)
#
# None

# %%
import torch # for: torch.sin,
import numpy as np # for: np.exp, np.sum

# %%
### Problem

# %%
## model
M = 100 # number of trajectories (batch size)
N = 10 # 20 # 50 # number of time snapshots
D = 4 # 2 # 100 # number (even) of dimensions

layer_size = 256 # 256
    
layers = [D+1] + 4*[layer_size] + [1]
# print( layers )
    
Xi = torch.from_numpy(np.array([1.0,0.5]*int(D/2))[None,:]).float()
# print(Xi.shape, Xi)
T = 1.0
s = 0.5
act_func = torch.nn.functional.relu # torch.sin # torch.tanh
    
model = BSB_Raissi(Xi, T,   M, N, D,   layers, act_func = act_func, s=s)
print( f'model = {model}' )
print( f'model.loss_n = {model.loss_n}' )
print( f'model.tool = {model.tool}' )
print( f"hasattr(self, 'act_func')={hasattr(model, 'act_func')}" )
print(model.loss_history, model.it_loss_history)

print( f'model.fn_u={model.fn_u}, model.fn_u.fc={model.fn_u.fc}' )
# Out:
# model = model_BSB_Raissi: s=0.5, T=1.0, D=4, Xi[0:4]=tensor([[1.0000, 0.5000, 1.0000, 0.5000]]); 	 N=10;
# 	 NNparams: M=100, layers=[5, 256, 256, 256, 256, 1], act_func=<function relu at 0x0000028AF2628E50>, optimizer=<class 'torch.optim.adam.Adam'>;
# 	 Learning: it=0; ; r=0.05, sigma=0.4
# model.loss_n = 1
# model.tool = pyTorch
# hasattr(self, 'act_func')=True
# [] 10
# model.fn_u=neural_net(
#   (out): Linear(in_features=256, out_features=1, bias=True)
# ), model.fn_u.fc=[Linear(in_features=5, out_features=256, bias=True), Linear(in_features=256, out_features=256, bias=True), Linear(in_features=256, out_features=256, bias=True), Linear(in_features=256, out_features=256, bias=True)]

# %%
model.train(N_Iter = 15*10**2, learning_rate=1e-3) #, it_print=50) # 20000)
# Out:
# It: 100, Loss: 1.259e+01, Y0: 1.376, Time: 7.07, Learning Rate: 1.000e-03
# It: 200, Loss: 9.142e+00, Y0: 2.632, Time: 6.60, Learning Rate: 1.000e-03
# It: 300, Loss: 7.692e+00, Y0: 2.643, Time: 6.32, Learning Rate: 1.000e-03
# It: 400, Loss: 7.646e+00, Y0: 2.658, Time: 6.34, Learning Rate: 1.000e-03
# It: 500, Loss: 6.930e+00, Y0: 2.667, Time: 6.38, Learning Rate: 1.000e-03
# It: 600, Loss: 5.733e+00, Y0: 2.664, Time: 6.53, Learning Rate: 1.000e-03
# It: 700, Loss: 5.899e+00, Y0: 2.637, Time: 6.57, Learning Rate: 1.000e-03
# It: 800, Loss: 4.924e+00, Y0: 2.704, Time: 6.48, Learning Rate: 1.000e-03
# It: 900, Loss: 4.099e+00, Y0: 2.667, Time: 6.36, Learning Rate: 1.000e-03
# It: 1000, Loss: 3.447e+00, Y0: 2.694, Time: 6.43, Learning Rate: 1.000e-03
# It: 1100, Loss: 3.220e+00, Y0: 2.635, Time: 6.92, Learning Rate: 1.000e-03
# It: 1200, Loss: 2.717e+00, Y0: 2.669, Time: 7.34, Learning Rate: 1.000e-03
# It: 1300, Loss: 2.430e+00, Y0: 2.674, Time: 7.29, Learning Rate: 1.000e-03
# It: 1400, Loss: 2.226e+00, Y0: 2.661, Time: 7.94, Learning Rate: 1.000e-03
# It: 1500, Loss: 1.809e+00, Y0: 2.689, Time: 6.66, Learning Rate: 1.000e-03

# %%
model.train(N_Iter = 15*10**2, learning_rate=1e-2, it_print=50) # 20000)
# Out:
# It: 1550, Loss: 1.326e+00, Y0: 2.627, Time: 3.25, Learning Rate: 1.000e-02
# It: 1600, Loss: 9.996e-01, Y0: 2.788, Time: 3.26, Learning Rate: 1.000e-02
# It: 1650, Loss: 1.075e+00, Y0: 2.794, Time: 3.57, Learning Rate: 1.000e-02
# It: 1700, Loss: 8.425e-01, Y0: 2.807, Time: 3.67, Learning Rate: 1.000e-02
# It: 1750, Loss: 7.964e-01, Y0: 2.810, Time: 3.52, Learning Rate: 1.000e-02
# It: 1800, Loss: 5.954e-01, Y0: 2.811, Time: 3.45, Learning Rate: 1.000e-02
# It: 1850, Loss: 8.234e-01, Y0: 2.813, Time: 3.14, Learning Rate: 1.000e-02
# It: 1900, Loss: 7.690e-01, Y0: 2.813, Time: 3.20, Learning Rate: 1.000e-02
# It: 1950, Loss: 7.069e-01, Y0: 2.811, Time: 3.17, Learning Rate: 1.000e-02
# It: 2000, Loss: 7.391e-01, Y0: 2.812, Time: 3.18, Learning Rate: 1.000e-02
# It: 2050, Loss: 6.245e-01, Y0: 2.810, Time: 3.36, Learning Rate: 1.000e-02
# It: 2100, Loss: 8.128e-01, Y0: 2.809, Time: 3.25, Learning Rate: 1.000e-02
# It: 2150, Loss: 7.552e-01, Y0: 2.810, Time: 3.27, Learning Rate: 1.000e-02
# It: 2200, Loss: 6.545e-01, Y0: 2.811, Time: 3.75, Learning Rate: 1.000e-02
# It: 2250, Loss: 6.783e-01, Y0: 2.811, Time: 3.13, Learning Rate: 1.000e-02
# It: 2300, Loss: 6.185e-01, Y0: 2.812, Time: 3.43, Learning Rate: 1.000e-02
# It: 2350, Loss: 7.812e-01, Y0: 2.816, Time: 3.67, Learning Rate: 1.000e-02
# It: 2400, Loss: 7.931e-01, Y0: 2.815, Time: 4.12, Learning Rate: 1.000e-02
# It: 2450, Loss: 8.102e-01, Y0: 2.814, Time: 3.53, Learning Rate: 1.000e-02
# It: 2500, Loss: 5.610e-01, Y0: 2.814, Time: 3.23, Learning Rate: 1.000e-02
# It: 2550, Loss: 5.495e-01, Y0: 2.814, Time: 3.24, Learning Rate: 1.000e-02
# It: 2600, Loss: 5.602e-01, Y0: 2.817, Time: 3.24, Learning Rate: 1.000e-02
# It: 2650, Loss: 6.207e-01, Y0: 2.818, Time: 3.28, Learning Rate: 1.000e-02
# It: 2700, Loss: 6.048e-01, Y0: 2.820, Time: 3.28, Learning Rate: 1.000e-02
# It: 2750, Loss: 5.795e-01, Y0: 2.818, Time: 3.25, Learning Rate: 1.000e-02
# It: 2800, Loss: 6.727e-01, Y0: 2.819, Time: 3.36, Learning Rate: 1.000e-02
# It: 2850, Loss: 6.388e-01, Y0: 2.822, Time: 3.23, Learning Rate: 1.000e-02
# It: 2900, Loss: 6.897e-01, Y0: 2.824, Time: 3.35, Learning Rate: 1.000e-02
# It: 2950, Loss: 5.121e-01, Y0: 2.823, Time: 3.49, Learning Rate: 1.000e-02
# It: 3000, Loss: 5.477e-01, Y0: 2.823, Time: 3.21, Learning Rate: 1.000e-02

# %%
import matplotlib.pyplot as plt

# %%
# print(model.loss_history)
lh_arr = np.array(model.loss_history).T
print( lh_arr.shape )
# print( lh_arr )
# Out:
# (2, 300)
# <ipython-input-11-81102754d8db>:2: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   lh_arr = np.array(model.loss_history).T

# %%
plt.plot( lh_arr[0], lh_arr[1] )
plt.grid()

# %%
t_test_, W_test_ = model.fetch_minibatch()
X_pred_, Y_pred_ = model.predict(Xi, t_test_, W_test_)
t_test = t_test_.detach().numpy()
X_pred = X_pred_.detach().numpy()
Y_pred = Y_pred_.detach().numpy()
# print(X_pred_, Y_pred_, sep='\n')

# %%
Y_test = np.reshape(model.u_exact(np.reshape(t_test[0:M,:,:],[-1,1]), np.reshape(X_pred[0:M,:,:],[-1,D])),[M,-1,1])
print(Y_test[0,0,0])
# Out:
# 2.7767768

# %%
res = (t_test, X_pred, Y_pred, Y_test)

# %%
from FBSNNs_plots import plot_results # *

# %%
fig = plot_results(model, res, flag_err_info=1)
# Out:
# ..\FBSNNs_plots.py:40: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   it,loss = np.array(model.loss_history).T[:,-1]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-44ffcbfa106e> in <module>
# ----> 1 fig = plot_results(model, res, flag_err_info=1)
#
# ~\Documents\_iPyNB\___diss_ipynb\non-linear_eq_solution\__FBSNNs_MY\_my FnLPDEs_FBSNNs\FBSNNs_tf1\FBSNNs_plots.py in plot_results(model, res, r, flag_err_info, u_name, Y_name, ax)
#      39     rel_err_t0 = abs( (Y_pred[0,0,0]-Y_test[0,0,0])/Y_test[0,0,0] ) # ошибка в значении u(0, xi)
#      40     it,loss = np.array(model.loss_history).T[:,-1]
# ---> 41     nn_info1 = f'N={model.N}, M={model.M}, layers={model.layers}, \n act_f={model.act_func_name}, it={it}, loss={loss:.4e}\n'
#      42     nn_info2 = ''
#      43     # if hasattr(model, 'loss_n'): nn_info2 = nn_info2 + f'loss_n = {model.loss_n}   '
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\module.py in __getattr__(self, name)
#    1128             if name in modules:
#    1129                 return modules[name]
# -> 1130         raise AttributeError("'{}' object has no attribute '{}'".format(
#    1131             type(self).__name__, name))
#    1132
#
# AttributeError: 'BSB_Raissi' object has no attribute 'act_func_name'

# %%
    samples = 5
    
    plt.figure()
    plt.plot(t_test[0:1,:,0].T,Y_pred[0:1,:,0].T,'b',label='Learned $u(t,X_t)$')
    plt.plot(t_test[0:1,:,0].T,Y_test[0:1,:,0].T,'r--',label='Exact $u(t,X_t)$')
    plt.plot(t_test[0:1,-1,0],Y_test[0:1,-1,0],'ko',label='$Y_T = u(T,X_T)$')
    
    plt.plot(t_test[1:samples,:,0].T,Y_pred[1:samples,:,0].T,'b')
    plt.plot(t_test[1:samples,:,0].T,Y_test[1:samples,:,0].T,'r--')
    plt.plot(t_test[1:samples,-1,0],Y_test[1:samples,-1,0],'ko')

    plt.plot([model.s],Y_test[0,0,0],'ks',label='$Y_0 = u(0,X_0)$')
    
    plt.xlabel('$t$')
    plt.ylabel('$Y_t = u(t,X_t)$')
    plt.title(f'{model.D}-dimensional Black-Scholes-Barenblatt')
    plt.legend()
